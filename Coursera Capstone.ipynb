# %% [markdown]
# # Coursera Capstone Project

# %% [markdown]
# This notebook details the results of the coursera capstone project

# %% [markdown]
# <em>Let's start by importing the numpy and pandas libraries</em>

# %%
import numpy as np
import pandas as pd

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ##  Week 3 Assignment Part I: Segmenting and Clustering Neighborhoods in Toronto

# %%
# !pip install beautifulsoup4
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from beautifulsoup4) (1.7.1)

# %%
import requests
wiki_url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M?oldformat=true'
wiki_page = requests.get(wiki_url).text  # import the html text form the wikipedia page

soup = BeautifulSoup(wiki_page, 'html.parser') # use the BeautifulSOup package to parse the HTML

# %%
# obtain the table data contained in the HTML
table = soup.find('table',{'class':'wikitable sortable'})
links = table.find_all('td')
links[0].text
# Out:
# 'M1A\n'

# %% [markdown]
# Now that we have isolated the data from the HTML we can proceed to prreprocess and clean the data.

# %%
list_items = []
postcodes = []
borough = []
neighborhood = []
# take all the content present in 'links' and copy to a new variable to have it in a list form
for index in links:
    list_items.append(index.text)
    
# filter the items in the list into postocde, borough and neighborhood
postcodes_tmp = list_items[::3]
borough_tmp = list_items[1::3]
neighborhood_tmp = list_items[2::3]
print('The number of elements in postcodes are: ', len(postcodes_tmp))
print('The number of elements in borough are: ', len(borough_tmp))
print('The number of elements in neighborhood are: ', len(neighborhood_tmp))

# clean the data from unwanted poscripts \n
postcodes.extend([s.strip('\n') for s in postcodes_tmp])
borough.extend([s.strip('\n') for s in borough_tmp])
neighborhood.extend([s.strip('\n') for s in neighborhood_tmp])

# transform into a pandas dataframe
df_postcodes = pd.DataFrame(postcodes)
df_borough = pd.DataFrame(borough)
df_neighborhood = pd.DataFrame(neighborhood)

df = pd.concat([df_postcodes, df_borough, df_neighborhood], axis=1)
columns_name = ['PostalCode', 'Borough', 'Neighborhood']
df.columns = columns_name

# drop rows which have not a borough assigned
df.drop(df[df['Borough'] == 'Not assigned'].index, inplace=True)
df.reset_index(drop=True)
# Out:
# The number of elements in postcodes are:  180
# The number of elements in borough are:  180
# The number of elements in neighborhood are:  180
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# ..         ...               ...
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# 5              Islington Avenue, Humber Valley Village
# 6                                       Malvern, Rouge
# 7                                            Don Mills
# 8                      Parkview Hill, Woodbine Gardens
# 9                             Garden District, Ryerson
# 10                                           Glencairn
# 11   West Deane Park, Princess Gardens, Martin Grov...
# 12              Rouge Hill, Port Union, Highland Creek
# 13                                           Don Mills
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Wilson Heights, Downsview North
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73                  North Toronto West,  Lawrence Park
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, St. Phillips, Martin Grove ...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      University of Toronto, Harbord
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Tam O'Shanter, Sullivan
# 83                         Moore Park, Summerhill East
# 84           Kensington Market, Chinatown, Grange Park
# 85   Milliken, Agincourt North, Steeles East, L'Amo...
# 86   Summerhill West, Rathnelly, South Hill, Forest...
# 87   CN Tower, King and Spadina, Railway Lands, Har...
# 88        New Toronto, Mimico South, Humber Bay Shores
# 89   South Steeles, Silverstone, Humbergate, Jamest...
# 90                       Steeles West, L'Amoreaux West
# 91                                            Rosedale
# 92                                      Stn A PO Boxes
# 93                              Alderwood, Long Branch
# 94                 Northwest, West Humber - Clairville
# 95                                         Upper Rouge
# 96                         St. James Town, Cabbagetown
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
df.shape # display number of rows and columns
# Out:
# (103, 3)

# %% [markdown]
# ## Week 3 PART II Assignment: Add location data to the neighborhoods

# %%
import geocoder # import geocoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-5a878079f829> in <module>
# ----> 1 import geocoder # import geocoder
#
# ModuleNotFoundError: No module named 'geocoder'

# %% [markdown]
# The package geocoder is not working at the moment when this code has been written. The code has been written detailing the methodology. However the location data will be retrieved via a previously stored .csv file.

# %%
## initialize your variable to None
#coord = []
#latitude = []
#longitude = []
## initialize your variable to None
#lat_lng_coords = None
## loop until you get the coordinates
#for i in range(0,len(df)):
#    while(lat_lng_coords is None):
#        g = geocoder.google('{}, Toronto, Ontario'.format(df.iloc[i,0]))
#        lat_lng_coords = g.latlng
#
#
#latitude = lat_lng_coords[0]
#longitude = lat_lng_coords[1]

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# sort the dataframe containing the location data according to the postal code order in the original dataframe
df_location = df_location.set_index('Postal Code')
df_location = df_location.reindex(index=df['PostalCode'])
df_location = df_location.reset_index()
df_location.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M3A  43.753259 -79.329656
# 1        M4A  43.725882 -79.315572
# 2        M5A  43.654260 -79.360636
# 3        M6A  43.718518 -79.464763
# 4        M7A  43.662301 -79.389494

# %%
df.reset_index(drop=True,inplace=True)
df[['Latitude','Longitude']] = df_location[['Latitude','Longitude']]
df.head(5)
# Out:
#   PostalCode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494
